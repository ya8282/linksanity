# %% [markdown]
# # Sample Notebook
#
# See the [docs](https://example.com/docs) for details.

# %%
# See https://code-comment.example.com/should-not-be-scanned for context
url = "https://code-string.example.com/also-not-scanned"
print(url)

# %% [markdown]
# ## Notes
#
# Some intro text.
#
# More filler text here.
#
# And here is a [broken link](https://broken.example.com/does-not-exist) on a later line.
